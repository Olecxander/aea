# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("applesHoney.csv")

# %%
df.describe()
# Out:
#        sample_number        sugar           ph           ec     potassium  \
# count   2.785000e+03  2782.000000  2782.000000  2782.000000   2783.000000
# mean    2.014773e+11     3.739324     5.883724    10.651179   5648.761534
# std     1.081757e+10     1.269632     1.236622     2.007055   1391.884809
# min     3.971600e+04     0.000000     0.000000     0.000000      0.000000
# 25%     2.020053e+11     2.900000     5.490000     9.750000   4772.185000
# 50%     2.021061e+11     3.600000     5.720000    10.800000   5676.340000
# 75%     2.022071e+11     4.500000     5.930000    11.820000   6511.560000
# max     2.023061e+11    10.400000    15.680000    18.310000  10957.729000
#
#            calcium    magnesium       sodium     ammonium  no3_nitrate  ...  \
# count  2783.000000  2783.000000  2783.000000  2782.000000  2782.000000  ...
# mean   1681.148951  1035.178312    37.792407    51.312817    22.639615  ...
# ...

# %%
df.shape
# Out:
# (2785, 33)

# %%
df.dtypes
# Out:
# external_id             object
# sample_date             object
# sample_number            int64
# plant_part              object
# business_name           object
# location_name           object
# plot_name               object
# variety_name            object
# crop_name               object
# lab_name                object
# set_id                  object
# sugar                  float64
# ph                     float64
# ec                     float64
# potassium              float64
# calcium                float64
# magnesium              float64
# sodium                 float64
# ammonium               float64
# no3_nitrate            float64
# nitrogen_in_nitrate    float64
# nitrogen               float64
# chloride               float64
# phosphorous            float64
# silica                 float64
# iron                   float64
# manganese              float64
# zinc                   float64
# boron                  float64
# copper                 float64
# ...

# %%
numerical_columns = df.select_dtypes(include=['float64'])

# %%
correlation_matrix = numerical_columns.corr().round(4)
correlation_matrix
# Out:
#                       sugar      ph      ec  potassium  calcium  magnesium  \
# sugar                1.0000  0.1832 -0.0474     0.0991   0.0797     0.1429
# ph                   0.1832  1.0000 -0.3981     0.0347   0.0563     0.0797
# ec                  -0.0474 -0.3981  1.0000     0.6042   0.1121     0.1221
# potassium            0.0991  0.0347  0.6042     1.0000  -0.1649    -0.0928
# calcium              0.0797  0.0563  0.1121    -0.1649   1.0000     0.7349
# magnesium            0.1429  0.0797  0.1221    -0.0928   0.7349     1.0000
# sodium              -0.0222  0.0109  0.2015     0.0483   0.2094     0.2729
# ammonium            -0.0506 -0.0715 -0.0455    -0.0605  -0.2838    -0.1515
# no3_nitrate         -0.0166  0.0565 -0.0417    -0.0240   0.0179     0.0280
# nitrogen_in_nitrate -0.0174  0.0562 -0.0417    -0.0232   0.0179     0.0279
# nitrogen            -0.2124 -0.0691  0.0674     0.0790  -0.0819    -0.0685
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)

plt.title('Correlation Matrix')
plt.xlabel('Variables')
plt.ylabel('Variables')

plt.show()

# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you already have your dataset loaded into a dataframe named 'df'

# Get the unique 'plant_part' values
unique_plant_parts = df['plant_part'].unique()

# Perform correlation analysis for each 'plant_part'
for plant_part in unique_plant_parts:
    # Filter the dataframe for the specific 'plant_part'
    subset_df = df[df['plant_part'] == plant_part]
    
    # Select only the numerical columns for correlation analysis
    numerical_columns = subset_df.select_dtypes(include=['float64'])
    
    print(plant_part + "sup")
# Out:
# Leaf (old)sup
# Leaf (young)sup
# Leaf (middle)sup

# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you already have your dataset loaded into a dataframe named 'df'

# Get the unique 'plant_part' values
unique_plant_parts = df['plant_part'].unique()

# Perform correlation analysis for each 'plant_part'
for plant_part in unique_plant_parts:
    # Filter the dataframe for the specific 'plant_part'
    subset_df = df[df['plant_part'] == plant_part]
    
    # Select only the numerical columns for correlation analysis
    numerical_columns = subset_df.select_dtypes(include=['float64'])
    
    
    
    # Create the correlation matrix
    correlation_matrix = numerical_columns.corr()
    
    # Count the number of observations in the subset
    num_observations = subset_df.shape[0]
    
    # Print the correlation matrix and observation count for the current 'plant_part'
    print(f"Correlation matrix for plant_part '{plant_part}':")
    print("Number of observations:", num_observations)
    print(correlation_matrix)
    print("\n")
    
    # Print the t-test results
    print("T-Statistic:", t_statistic)
    print("P-Value:", p_value)
    print("\n")
    
    # Plot the correlation matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
    plt.title(f"Correlation Matrix for plant_part '{plant_part}'")
    plt.xlabel('Variables')
    plt.ylabel('Variables')
    plt.show()
# Out:
# Correlation matrix for plant_part 'Leaf (old)':
# Number of observations: 1403
#                         sugar        ph        ec  potassium   calcium  \
# sugar                1.000000  0.208458 -0.063282   0.055467  0.111120
# ph                   0.208458  1.000000 -0.378810   0.038842  0.068189
# ec                  -0.063282 -0.378810  1.000000   0.634386  0.089345
# potassium            0.055467  0.038842  0.634386   1.000000 -0.139812
# calcium              0.111120  0.068189  0.089345  -0.139812  1.000000
# magnesium            0.095794  0.058913  0.131860  -0.109055  0.758112
# sodium              -0.006199  0.015817  0.197607   0.071791  0.183722
# ammonium            -0.050278 -0.056329 -0.016822  -0.068885 -0.245083
# no3_nitrate         -0.030682  0.039145 -0.028086  -0.027526  0.012149
# nitrogen_in_nitrate -0.031484  0.039088 -0.027877  -0.026622  0.011971
# nitrogen            -0.204468 -0.068376  0.082593   0.103191 -0.087060
# ...

# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind

# Assuming you have two correlation matrices stored as 'correlation_matrix1' and 'correlation_matrix2'

# Flatten the correlation matrices into 1-D arrays
correlation_array1 = np.array(correlation_matrix1.values.flatten())
correlation_array2 = np.array(correlation_matrix2.values.flatten())

# Perform pairwise t-tests on the correlation coefficients
t_statistic, p_value = ttest_ind(correlation_array1, correlation_array2)

# Print the results
print("T-Statistic:", t_statistic)
print("P-Value:", p_value)
